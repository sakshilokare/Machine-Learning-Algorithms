# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("diabetes1.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.tail
# Out:
# <bound method NDFrame.tail of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]>

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
plt.figure(figsize=(10,10))
plotnumber = 1
for i in data:
    plt.subplot(3,3,plotnumber)
    #sns.histplot(x = data[i])
    sns.histplot(x = data[i],hue=data.Outcome)
    plotnumber += 1
plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
plotnumber = 1
for i in data:
    plt.subplot(3,3,plotnumber)
    #sns.boxplot(x = data[i])
    sns.boxplot(x = data[i],hue=data.Outcome)
    plotnumber += 1
plt.tight_layout()

# %%
data.loc[data['Glucose']==0,'Glucose']=np.median(data.Glucose)

# %%
data.loc[data['Glucose']==0,'Glucose']
# Out:
# Series([], Name: Glucose, dtype: int64)

# %%
data.SkinThickness.unique()
# Out:
# array([35, 29,  0, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31,
#        37, 42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40,
#        51, 56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
data.BMI.unique()
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5,  0. , 37.6,
#        38. , 27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4,
#        39.8, 29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8,
#        19.9, 27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4,
#        27.4, 42. , 29.7, 28. , 39.1, 19.4, 24.2, 24.4, 33.7, 34.7, 23. ,
#        37.7, 46.8, 40.5, 41.5, 25. , 25.4, 32.8, 32.5, 42.7, 19.6, 28.9,
#        28.6, 43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4, 29.3, 24.6, 48.8,
#        32.4, 38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4, 28.7, 49.7, 39. ,
#        26.1, 22.5, 39.6, 29.5, 34.3, 37.4, 33.3, 31.2, 28.2, 53.2, 34.2,
#        26.8, 55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8, 36.9, 39.5,
#        27.3, 21.9, 40.6, 47.9, 50. , 25.2, 40.9, 37.2, 44.2, 29.9, 31.9,
#        28.4, 43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 30.4,
#        52.3, 24.3, 22.9, 34.8, 30.9, 40.1, 23.9, 37.5, 35.5, 42.8, 42.6,
#        41.8, 35.8, 37.8, 28.8, 23.6, 35.7, 36.7, 45.2, 44. , 46.2, 35. ,
#        43.6, 44.1, 18.4, 29.2, 25.9, 32.1, 36.3, 40. , 25.1, 27.5, 45.6,
#        27.8, 24.9, 25.3, 37.9, 27. , 26. , 38.7, 20.8, 36.1, 30.7, 32.3,
#        52.9, 21. , 39.7, 25.5, 26.2, 19.3, 38.1, 23.5, 45.5, 23.1, 39.9,
#        36.8, 21.8, 41. , 42.2, 34.4, 27.2, 36.5, 29.8, 39.2, 38.4, 36.2,
#        48.3, 20. , 22.3, 45.7, 23.7, 22.1, 42.1, 42.4, 18.2, 26.4, 45.3,
#        37. , 24.5, 32.2, 59.4, 21.2, 26.7, 30.2, 46.1, 41.3, 38.8, 35.2,
#        42.3, 40.7, 46.5, 33.5, 37.3, 30.3, 26.3, 21.7, 36.4, 28.5, 26.9,
#        38.6, 31.3, 19.5, 20.1, 40.8, 23.4, 28.3, 38.9, 57.3, 35.6, 49.6,
#        44.6, 24.1, 44.5, 41.2, 49.3, 46.3])

# %%
data.Insulin.unique()
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
#        183,  91,  46, 440, 159, 540, 200, 335, 387,  22, 291, 392, 178,
#        127, 510,  16, 112], dtype=int64)

# %%
data.Pregnancies.unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %%
data.BloodPressure.unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
data.DiabetesPedigreeFunction.unique()
# Out:
# array([0.627, 0.351, 0.672, 0.167, 2.288, 0.201, 0.248, 0.134, 0.158,
#        0.232, 0.191, 0.537, 1.441, 0.398, 0.587, 0.484, 0.551, 0.254,
#        0.183, 0.529, 0.704, 0.388, 0.451, 0.263, 0.205, 0.257, 0.487,
#        0.245, 0.337, 0.546, 0.851, 0.267, 0.188, 0.512, 0.966, 0.42 ,
#        0.665, 0.503, 1.39 , 0.271, 0.696, 0.235, 0.721, 0.294, 1.893,
#        0.564, 0.586, 0.344, 0.305, 0.491, 0.526, 0.342, 0.467, 0.718,
#        0.962, 1.781, 0.173, 0.304, 0.27 , 0.699, 0.258, 0.203, 0.855,
#        0.845, 0.334, 0.189, 0.867, 0.411, 0.583, 0.231, 0.396, 0.14 ,
#        0.391, 0.37 , 0.307, 0.102, 0.767, 0.237, 0.227, 0.698, 0.178,
#        0.324, 0.153, 0.165, 0.443, 0.261, 0.277, 0.761, 0.255, 0.13 ,
#        0.323, 0.356, 0.325, 1.222, 0.179, 0.262, 0.283, 0.93 , 0.801,
#        0.207, 0.287, 0.336, 0.247, 0.199, 0.543, 0.192, 0.588, 0.539,
#        0.22 , 0.654, 0.223, 0.759, 0.26 , 0.404, 0.186, 0.278, 0.496,
#        0.452, 0.403, 0.741, 0.361, 1.114, 0.457, 0.647, 0.088, 0.597,
#        0.532, 0.703, 0.159, 0.268, 0.286, 0.318, 0.272, 0.572, 0.096,
#        1.4  , 0.218, 0.085, 0.399, 0.432, 1.189, 0.687, 0.137, 0.637,
#        0.833, 0.229, 0.817, 0.204, 0.368, 0.743, 0.722, 0.256, 0.709,
#        0.471, 0.495, 0.18 , 0.542, 0.773, 0.678, 0.719, 0.382, 0.319,
#        0.19 , 0.956, 0.084, 0.725, 0.299, 0.244, 0.745, 0.615, 1.321,
#        0.64 , 0.142, 0.374, 0.383, 0.578, 0.136, 0.395, 0.187, 0.905,
#        0.15 , 0.874, 0.236, 0.787, 0.407, 0.605, 0.151, 0.289, 0.355,
#        0.29 , 0.375, 0.164, 0.431, 0.742, 0.514, 0.464, 1.224, 1.072,
#        0.805, 0.209, 0.666, 0.101, 0.198, 0.652, 2.329, 0.089, 0.645,
#        0.238, 0.394, 0.293, 0.479, 0.686, 0.831, 0.582, 0.446, 0.402,
#        1.318, 0.329, 1.213, 0.427, 0.282, 0.143, 0.38 , 0.284, 0.249,
#        0.926, 0.557, 0.092, 0.655, 1.353, 0.612, 0.2  , 0.226, 0.997,
#        0.933, 1.101, 0.078, 0.24 , 1.136, 0.128, 0.422, 0.251, 0.677,
#        0.296, 0.454, 0.744, 0.881, 0.28 , 0.259, 0.619, 0.808, 0.34 ,
#        0.434, 0.757, 0.613, 0.692, 0.52 , 0.412, 0.84 , 0.839, 0.156,
#        0.215, 0.326, 1.391, 0.875, 0.313, 0.433, 0.626, 1.127, 0.315,
#        0.345, 0.129, 0.527, 0.197, 0.731, 0.148, 0.123, 0.127, 0.122,
#        1.476, 0.166, 0.932, 0.343, 0.893, 0.331, 0.472, 0.673, 0.389,
#        0.485, 0.349, 0.279, 0.346, 0.252, 0.243, 0.58 , 0.559, 0.302,
#        0.569, 0.378, 0.385, 0.499, 0.306, 0.234, 2.137, 1.731, 0.545,
#        0.225, 0.816, 0.528, 0.509, 1.021, 0.821, 0.947, 1.268, 0.221,
#        0.66 , 0.239, 0.949, 0.444, 0.463, 0.803, 1.6  , 0.944, 0.196,
#        0.241, 0.161, 0.135, 0.376, 1.191, 0.702, 0.674, 1.076, 0.534,
#        1.095, 0.554, 0.624, 0.219, 0.507, 0.561, 0.421, 0.516, 0.264,
#        0.328, 0.233, 0.108, 1.138, 0.147, 0.727, 0.435, 0.497, 0.23 ,
#        0.955, 2.42 , 0.658, 0.33 , 0.51 , 0.285, 0.415, 0.381, 0.832,
#        0.498, 0.212, 0.364, 1.001, 0.46 , 0.733, 0.416, 0.705, 1.022,
#        0.269, 0.6  , 0.571, 0.607, 0.17 , 0.21 , 0.126, 0.711, 0.466,
#        0.162, 0.419, 0.63 , 0.365, 0.536, 1.159, 0.629, 0.292, 0.145,
#        1.144, 0.174, 0.547, 0.163, 0.738, 0.314, 0.968, 0.409, 0.297,
#        0.525, 0.154, 0.771, 0.107, 0.493, 0.717, 0.917, 0.501, 1.251,
#        0.735, 0.804, 0.661, 0.549, 0.825, 0.423, 1.034, 0.16 , 0.341,
#        0.68 , 0.591, 0.3  , 0.121, 0.502, 0.401, 0.601, 0.748, 0.338,
#        0.43 , 0.892, 0.813, 0.693, 0.575, 0.371, 0.206, 0.417, 1.154,
#        0.925, 0.175, 1.699, 0.682, 0.194, 0.4  , 0.1  , 1.258, 0.482,
#        0.138, 0.593, 0.878, 0.157, 1.282, 0.141, 0.246, 1.698, 1.461,
#        0.347, 0.362, 0.393, 0.144, 0.732, 0.115, 0.465, 0.649, 0.871,
#        0.149, 0.695, 0.303, 0.61 , 0.73 , 0.447, 0.455, 0.133, 0.155,
#        1.162, 1.292, 0.182, 1.394, 0.217, 0.631, 0.88 , 0.614, 0.332,
#        0.366, 0.181, 0.828, 0.335, 0.856, 0.886, 0.439, 0.253, 0.598,
#        0.904, 0.483, 0.565, 0.118, 0.177, 0.176, 0.295, 0.441, 0.352,
#        0.826, 0.97 , 0.595, 0.317, 0.265, 0.646, 0.426, 0.56 , 0.515,
#        0.453, 0.785, 0.734, 1.174, 0.488, 0.358, 1.096, 0.408, 1.182,
#        0.222, 1.057, 0.766, 0.171])

# %%
data.Glucose.unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,  62, 131, 112, 113,  74,  83, 136,  80,
#        123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160, 124,
#        162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188, 152,
#        104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,  91,
#        165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98, 127,
#         82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174, 199,
#         56, 169, 149,  65, 190], dtype=int64)

# %%
data.loc[data['BloodPressure']==0,'BloodPressure']=np.median(data.BloodPressure)
data.loc[data['SkinThickness']==0,'SkinThickness']=np.median(data.SkinThickness)
data.loc[data['BMI']==0,'BMI']=np.median(data.BMI)
data.loc[data['Insulin']==0,'Insulin']=int(np.median(data.Insulin))

# %%
data.loc[data.BloodPressure < 40,'BloodPressure']=40

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128213       0.207882       0.032568
# Glucose                      0.128213  1.000000       0.218003       0.172143
# BloodPressure                0.207882  0.218003       1.000000       0.150971
# SkinThickness                0.032568  0.172143       0.150971       1.000000
# Insulin                     -0.056022  0.357146      -0.030579       0.238321
# BMI                          0.021546  0.231400       0.288693       0.546951
# DiabetesPedigreeFunction    -0.033523  0.137327      -0.002866       0.142977
# Age                          0.544341  0.266909       0.326583       0.054514
# Outcome                      0.221898  0.492782       0.167178       0.189065
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.056022  0.021546                 -0.033523
# Glucose                   0.357146  0.231400                  0.137327
# BloodPressure            -0.030579  0.288693                 -0.002866
# SkinThickness             0.238321  0.546951                  0.142977
# Insulin                   1.000000  0.188976                  0.178173
# BMI                       0.188976  1.000000                  0.153506
# DiabetesPedigreeFunction  0.178173  0.153506                  1.000000
# Age                      -0.015892  0.025744                  0.033561
# Outcome                   0.148152  0.312249                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.266909  0.492782
# BloodPressure             0.326583  0.167178
# SkinThickness             0.054514  0.189065
# Insulin                  -0.015892  0.148152
# BMI                       0.025744  0.312249
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
X= data.drop('Outcome',axis=1)
Y = data.Outcome

# %%
Y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train_raw, x_test_raw, y_train, y_test = train_test_split(X,Y,test_size= 0.25,random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scal = MinMaxScaler()
X_scaled = scal.fit_transform(x_train_raw)

# %%
X_scaled
# Out:
# array([[0.76470588, 0.5483871 , 0.3902439 , ..., 0.44376278, 0.20964987,
#         0.38333333],
#        [0.23529412, 0.5483871 , 0.56097561, ..., 0.34560327, 0.06532878,
#         0.03333333],
#        [0.17647059, 0.10967742, 0.51219512, ..., 0.33128834, 0.0704526 ,
#         0.41666667],
#        ...,
#        [0.58823529, 0.36774194, 0.56097561, ..., 0.5603272 , 0.45175064,
#         0.28333333],
#        [0.        , 0.62580645, 0.3902439 , ..., 0.49488753, 0.05422716,
#         0.13333333],
#        [0.        , 0.52258065, 0.68292683, ..., 0.08793456, 0.07856533,
#         0.        ]])

# %%
x_train = pd.DataFrame(data=X_scaled, columns = data.columns[:8])

# %%
x_train
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.764706  0.548387       0.390244       0.400000  0.019231  0.443763
# 1       0.235294  0.548387       0.560976       0.218182  0.307692  0.345603
# 2       0.176471  0.109677       0.512195       0.363636  0.019231  0.331288
# 3       0.117647  0.238710       0.390244       0.127273  0.074519  0.243354
# 4       0.000000  0.374194       0.426829       0.272727  0.019231  0.282209
# ..           ...       ...            ...            ...       ...       ...
# 571     0.294118  0.612903       0.292683       0.490909  0.151442  0.212679
# 572     0.058824  0.335484       1.000000       0.272727  0.019231  0.085890
# 573     0.588235  0.367742       0.560976       0.527273  0.019231  0.560327
# 574     0.000000  0.625806       0.390244       0.272727  0.019231  0.494888
# 575     0.000000  0.522581       0.682927       0.272727  0.019231  0.087935
#
#      DiabetesPedigreeFunction       Age
# 0                    0.209650  0.383333
# 1                    0.065329  0.033333
# 2                    0.070453  0.416667
# 3                    0.200256  0.066667
# 4                    0.210931  0.000000
# ..                        ...       ...
# 571                  0.142186  0.083333
# 572                  0.055081  0.100000
# 573                  0.451751  0.283333
# 574                  0.054227  0.133333
# 575                  0.078565  0.000000
#
# [576 rows x 8 columns]

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test = scal.transform(x_test_raw)
x_test = pd.DataFrame(data=X_test, columns = data.columns[:8])
y_pred = LR.predict(x_test)

# %%
x1 = pd.DataFrame()
x1[0] = y_pred
x1[1] = y_test.values
x1[2] = y_pred-y_test.values
x1.rename(columns={0:"Y_pred"},inplace=True)
x1.rename(columns={1:"Y_test"},inplace=True)
x1.rename(columns={2:"Error"},inplace=True)
x1
# Out:
#      Y_pred  Y_test  Error
# 0         0       0      0
# 1         0       0      0
# 2         0       0      0
# 3         0       0      0
# 4         0       0      0
# ..      ...     ...    ...
# 187       0       0      0
# 188       1       1      0
# 189       0       0      0
# 190       0       1     -1
# 191       0       0      0
#
# [192 rows x 3 columns]

# %%
from sklearn.metrics import accuracy_score , precision_score, recall_score , f1_score , confusion_matrix , classification_report

# %%
acc = accuracy_score (y_test,y_pred)
print('Accuracy:',acc)
pr = precision_score (y_test,y_pred)
re = recall_score (y_test,y_pred)
f1 = f1_score (y_test,y_pred)
cm = confusion_matrix (y_test,y_pred)
print('Precisio:',pr,'\nRecall:',re,'\nF1:',f1,'\nConfusion Matrix:',cm)
print('Classification Report:\n',classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.7395833333333334
# Precisio: 0.6557377049180327
# Recall: 0.5797101449275363
# F1: 0.6153846153846154
# Confusion Matrix: [[102  21]
#  [ 29  40]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       123
#            1       0.66      0.58      0.62        69
#
#     accuracy                           0.74       192
#    macro avg       0.72      0.70      0.71       192
# weighted avg       0.73      0.74      0.74       192

# %%
#multi class classification
import seaborn
sns.get_dataset_names()
iris=sns.load_dataset('iris')

# %%
iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35       30  33.6
# 1            1       85             66             29       30  26.6
# 2            8      183             64             23       30  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail
# Out:
# <bound method NDFrame.tail of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35       30  33.6
# 1              1       85             66             29       30  26.6
# 2              8      183             64             23       30  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       30  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             23       30  30.1
# 767            1       93             70             31       30  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]>

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.436198      27.334635   94.408854
# std       3.369578   30.438286      11.938067       9.229014  105.695978
# min       0.000000   44.000000      40.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      23.000000   30.000000
# 50%       3.000000  117.000000      72.000000      23.000000   31.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450911                  0.471876   33.240885    0.348958
# std      6.875366                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
x = iris.drop(['species'],axis=1)
y = iris.species

# %%
xtrain_raw,xtest_raw,ytrain,ytest = train_test_split(x,y,test_size= 0.25,random_state=30)

# %%
#Model Creation
from sklearn.preprocessing import StandardScaler
scaler1 = StandardScaler()
col = x.columns
x_new = scaler1.fit_transform(xtrain_raw)
xtrain = pd.DataFrame(data=x_new,columns=col)

# %%
xtrain
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0        0.316107    -0.643610      0.151523     0.146151
# 1        1.682576    -0.194486      1.180043     0.545394
# 2        1.185678     0.254637      1.237183     1.476961
# 3        0.688780    -0.643610      1.065763     1.210799
# 4       -0.056567     2.051130     -1.448397    -1.317739
# ..            ...          ...           ...          ...
# 107     -0.429240    -1.766418      0.151523     0.146151
# 108      1.931025    -0.643610      1.351463     0.944637
# 109      1.061454     0.030075      1.065763     1.610042
# 110     -1.298811    -0.194486     -1.334117    -1.184658
# 111     -1.174587     1.152884     -1.334117    -1.450820
#
# [112 rows x 4 columns]

# %%
x_new = scaler1.transform(xtest_raw)
xtest = pd.DataFrame(data=x_new,columns=col)

# %%
xtest
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0      -0.553464     0.703760     -1.162697    -1.317739
# 1      -0.553464     1.826568     -1.162697    -1.051577
# 2      -1.547260     0.030075     -1.276977    -1.317739
# 3      -0.056567    -0.868171      0.780063     0.944637
# 4      -0.056567    -0.868171      0.094383     0.013070
# 5      -0.429240    -1.541856      0.037243    -0.120010
# 6       0.564556    -0.868171      0.665783     0.811556
# 7       1.061454    -0.194486      0.837203     1.476961
# 8       0.688780    -0.419048      0.322943     0.146151
# 9       1.806801    -0.419048      1.465743     0.811556
# 10     -1.795709    -0.194486     -1.391257    -1.317739
# 11      0.564556    -0.419048      1.065763     0.811556
# 12     -1.050362    -1.766418     -0.248457    -0.253091
# 13     -0.180791    -0.643610      0.208663     0.146151
# 14     -1.795709    -0.419048     -1.334117    -1.317739
# 15      0.440331    -0.419048      0.322943     0.146151
# 16     -0.801913     2.275692     -1.276977    -1.450820
# 17     -1.174587    -0.194486     -1.334117    -1.317739
# 18     -1.298811     0.703760     -1.048417    -1.317739
# 19      0.564556    -1.317295      0.665783     0.412313
# 20      0.564556    -0.643610      0.780063     0.412313
# 21     -1.795709     0.254637     -1.391257    -1.317739
# 22     -0.926138     0.928322     -1.334117    -1.317739
# 23     -1.050362     0.254637     -1.448397    -1.317739
# 24      2.179474    -0.194486      1.637163     1.210799
# 25      0.688780    -0.643610      1.065763     1.343880
# 26      0.067658     0.254637      0.608643     0.811556
# 27      0.564556     0.703760      1.065763     1.610042
# 28     -1.423036     0.254637     -1.391257    -1.317739
# 29      0.564556    -1.766418      0.380083     0.146151
# 30      1.309903     0.030075      0.951483     1.210799
# 31     -0.429240    -1.541856     -0.019897    -0.253091
# 32      1.185678    -0.194486      1.008623     1.210799
# 33      0.316107    -0.194486      0.665783     0.811556
# 34      2.303699    -1.092733      1.808583     1.476961
# 35      1.309903     0.030075      0.780063     1.476961
# 36     -0.926138    -1.317295     -0.419877    -0.120010
# 37      0.688780     0.030075      1.008623     0.811556

# %%
#print(xtrain,ytrain,ytest)
LR1 = LogisticRegression(multi_class='ovr')
LR1.fit(xtrain,ytrain)
ypred = LR1.predict(xtest)
x2 = pd.DataFrame()
x2[0] = ypred
x2[1]=ytest.values
x2.rename(columns={0:"Y_Pred"},inplace=True)
x2.rename(columns={1:"Y_Test"},inplace=True)
x2
# Out:
#         Y_Pred      Y_Test
# 0       setosa      setosa
# 1       setosa      setosa
# 2       setosa      setosa
# 3    virginica   virginica
# 4   versicolor  versicolor
# 5   versicolor  versicolor
# 6    virginica   virginica
# 7    virginica   virginica
# 8   versicolor  versicolor
# 9    virginica   virginica
# 10      setosa      setosa
# 11   virginica   virginica
# 12  versicolor  versicolor
# 13  versicolor  versicolor
# 14      setosa      setosa
# 15  versicolor  versicolor
# 16      setosa      setosa
# 17      setosa      setosa
# 18      setosa      setosa
# 19  versicolor  versicolor
# 20  versicolor   virginica
# 21      setosa      setosa
# 22      setosa      setosa
# 23      setosa      setosa
# 24   virginica   virginica
# 25   virginica   virginica
# 26   virginica  versicolor
# 27   virginica   virginica
# 28      setosa      setosa
# 29  versicolor  versicolor
# 30   virginica   virginica
# 31  versicolor  versicolor
# 32   virginica   virginica
# 33   virginica   virginica
# 34   virginica   virginica
# 35   virginica   virginica
# 36  versicolor  versicolor
# 37   virginica   virginica

# %%
print(accuracy_score(ytest,ypred))
print(precision_score(ytest,ypred,average='weighted'))
print(recall_score(ytest,ypred,average='weighted'))
print(f1_score(ytest,ypred,average='weighted'))
print(confusion_matrix(ytest,ypred),pd.crosstab(ytest,ypred))
print(classification_report(ytest,ypred))
# Out:
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# [[12  0  0]
#  [ 0 10  1]
#  [ 0  1 14]] col_0       setosa  versicolor  virginica
# species
# setosa          12           0          0
# versicolor       0          10          1
# virginica        0           1         14
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        12
#   versicolor       0.91      0.91      0.91        11
#    virginica       0.93      0.93      0.93        15
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.95      0.95        38
# weighted avg       0.95      0.95      0.95        38
